# %%
import pandas as pd
# Out:
# <ipython-input-1-7dd3504c366f>:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
sales_df = pd.read_csv('Centro Sales.csv', sep=';')
prices_df = pd.read_csv('Prices Centro.csv', sep=';')

# %%
sales_df['datetime'] = pd.to_datetime(sales_df['datetime'], format='%d-%m-%y %H:%M:%S')

# %%
filtered_sales = sales_df[(sales_df['shop'] == 100) & (sales_df['datetime'].dt.date == pd.to_datetime('01-01-23').date())]

# %%
prices_df = prices_df.sort_values(by=['art', 'price'], ascending=[True, False])

# %%
def get_price(group):
    if len(group) > 1:
        return group.iloc[1]
    else:
        return group.iloc[0]

# %%
price_to_use = prices_df.groupby('art').apply(get_price).reset_index(drop=True)
# Out:
# <ipython-input-15-ccf50e9e30e1>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   price_to_use = prices_df.groupby('art').apply(get_price).reset_index(drop=True)

# %%
merged_df = pd.merge(filtered_sales, price_to_use, on='art', how='left')

# %%
merged_df['total_sales'] = merged_df['quantity'] * merged_df['price']

# %%
total_sales_shop_100 = merged_df['total_sales'].sum()

total_sales_shop_100
# Out:
# 270
